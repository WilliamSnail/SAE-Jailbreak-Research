# %% [markdown]
# # 1️⃣ Introduction
#
# > ##### Objectives
# >
# > * Load model using the `nnsight` library,
# > * Learn some basics of HuggingFace models (e.g. tokenization, model output)
# > * Use it to extract & visualise GPT-J-6B's internal activations
# > * Load sae model corresponding to the model
#
# ### Reference:
# Tutoiral:
# > [Gemma Scope 2](https://colab.research.google.com/drive/1NhWjg7n0nhfW--CjtsOdw5A5J_-Bzn4r#scrollTo=nOBcV4om7mrT)
#
# > [SAE_Lens](https://decoderesearch.github.io/SAELens/latest/usage/#using-saes-without-transformerlens)
# https://colab.research.google.com/drive/1RMOvARSFvyqig8yHdsT7lfRQmXOpFlE4#scrollTo=yfDUxRx0wSRl

# %% [markdown]
# # Set-Up

# %%
try:
    import google.colab  # type: ignore
    from google.colab import output

    IS_COLAB = True
    # %pip install sae-lens transformer-lens sae-dashboard datasets
except:
    IS_COLAB = False
    from IPython import get_ipython  # type: ignore

    ipython = get_ipython()
    assert ipython is not None
    ipython.run_line_magic("load_ext", "autoreload")
    ipython.run_line_magic("autoreload", "2")

# %%
import logging
import os
import sys
import time
from collections import defaultdict
from pathlib import Path
from tqdm.auto import tqdm
import numpy as np
import pandas as pd

#import circuitsvis as cv
import einops
import numpy as np
import torch
import torch as t
import torch.nn as nn
from IPython.display import display, HTML
from jaxtyping import Float

from openai import OpenAI
from rich import print as rprint
from rich.table import Table
from torch import Tensor
from safetensors.torch import load_file

from transformers import AutoModelForCausalLM, BitsAndBytesConfig, AutoTokenizer


# Only doing inference, no need to safe grad to save memory
t.set_grad_enabled(False)

# Hide some info logging messages from nnsight
logging.disable(sys.maxsize)


# Check device
if t.backends.mps.is_available():
    device = "mps"
else:
    device = "cuda" if t.cuda.is_available() else "cpu"

print(f"Torch Device: {device}")
# Out:
# Torch Device: cuda

# %%
# =========================================
# NNSight and HuggingFace API Configuration
# =========================================

from nnsight import CONFIG

# If you have an API key & want to work remotely, 
# then set REMOTE = True, if not, then leave REMOTE = False.

# ===========
REMOTE = True
# ===========


if REMOTE and not IS_COLAB:

  from dotenv import load_dotenv
  if(load_dotenv()):
    # == Set API from .env file ==
    print("> Running on local device. API loaded from .env file")

    # > NNsight API Key
    CONFIG.set_default_api_key(os.getenv("NDIF_API_KEY")) 
    # > HF Token from .env file  
    os.environ['HF_TOKEN'] = os.getenv("HF_TOKEN")    

  else:
    raise ValueError("REMOTE is set to True but no .env file found.\n Please create a .env file or set API in the code.")
    
if IS_COLAB and REMOTE:
  print("> Running on Colab")
  from google.colab import userdata
  print("API loaded from Colab userdata")
  # > NNsight API Key 
  CONFIG.set_default_api_key(userdata.get('NDIF_API_KEY'))
  # > HF Token from 
  os.environ['HF_TOKEN'] = userdata.get('HF_TOKEN')
# Out:
# > Running on local device. API loaded from .env file

# %% [markdown]
# # 2️⃣ Load Model Using NNSIGHT
# Here, we'll discuss some important syntax for interacting with `nnsight` models. Since these models are extensions of HuggingFace models, some of this information (e.g. tokenization) applies to plain HuggingFace models as well as `nnsight` models, and some of it (e.g. forward passes) is specific to `nnsight`, i.e. it would work differently if you just had a standard HuggingFace model. Make sure to keep this distinction in mind, otherwise syntax can get confusing!
#
# 1. Tutoiral: [NNSIGHT Main Page](https://nnsight.net/)
# 2. Page: [NNSIGHT Remote Statues](https://nnsight.net/status/)
#
# ### Model config
#
# Each model comes with a `model.config`, which contains lots of useful information about the model (e.g. number of heads and layers, size of hidden layers, etc.). You can access this with `model.config`. Run the code below to see this in action, and to define some useful variables for later.

# %%
from pathlib import Path

# Set cache_dir only if not on Colab
cache_dir = None if IS_COLAB else str(Path.cwd().parent.parent / "hf_cache")

# %%
from nnsight import LanguageModel

# Load model
model = LanguageModel("google/gemma-3-1b-pt", device_map="auto", torch_dtype=t.bfloat16)
tokenizer = model.tokenizer

print("=== Entire config === \n", model.config)
# Out:
# === Entire config ===
#  Gemma3TextConfig {
#   "_sliding_window_pattern": 6,
#   "architectures": [
#     "Gemma3ForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "attn_logit_softcapping": null,
#   "bos_token_id": 2,
#   "cache_implementation": "hybrid",
#   "dtype": "bfloat16",
#   "eos_token_id": 1,
#   "final_logit_softcapping": null,
#   "head_dim": 256,
#   "hidden_activation": "gelu_pytorch_tanh",
#   "hidden_size": 1152,
#   "initializer_range": 0.02,
#   "intermediate_size": 6912,
#   "layer_types": [
#     "sliding_attention",
#     "sliding_attention",
#     "sliding_attention",
#     "sliding_attention",
#     "sliding_attention",
#     "full_attention",
#     "sliding_attention",
#     "sliding_attention",
#     "sliding_attention",
#     "sliding_attention",
#     "sliding_attention",
#     "full_attention",
#     "sliding_attention",
#     "sliding_attention",
#     "sliding_attention",
#     "sliding_attention",
#     "sliding_attention",
#     "full_attention",
#     "sliding_attention",
#     "sliding_attention",
#     "sliding_attention",
#     "sliding_attention",
#     "sliding_attention",
#     "full_attention",
#     "sliding_attention",
#     "sliding_attention"
#   ],
#   "max_position_embeddings": 32768,
#   "model_type": "gemma3_text",
#   "num_attention_heads": 4,
#   "num_hidden_layers": 26,
#   "num_key_value_heads": 1,
#   "pad_token_id": 0,
#   "query_pre_attn_scalar": 256,
#   "rms_norm_eps": 1e-06,
#   "rope_local_base_freq": 10000,
#   "rope_scaling": null,
#   "rope_theta": 1000000,
#   "sliding_window": 512,
#   "sliding_window_pattern": 6,
#   "transformers_version": "4.57.6",
#   "use_bidirectional_attention": false,
#   "use_cache": true,
#   "vocab_size": 262144
# }

# %% [markdown]
# ## Remote Execution
#
# 1. [NDIF](https://ndif.us/) is the complementary service to nnsight which allows users to perform interventions without model loading or requiring a GPU. Through NDIF, users can have access to a variety of models, remotely, with a wide range of sizes (up to 400+ Billion parameters!).
#   > You can visit https://nnsight.net/status/ to check current model serving, or, use the nnsight API to get the current status of the backend.
#
# 2. API Key: To access remote functionality on NDIF, you need to claim an API key at https://login.ndif.us.
# 3. Note: Make sure your HF_TOKEN is set to your environment. This step is required for both local and remote execution. More info at: https://huggingface.co/docs/huggingface_hub/en/quick-star
#
# 4. NDIF Tutorial:
# https://arena-chapter1-transformer-interp.streamlit.app/[1.4.2]_Function_Vectors_&_Model_Steering#remote-execution

# %%
# If you have an API key & want to work remotely, then set REMOTE = True
# and # If not, then leave REMOTE = False.

# ===========
REMOTE = True
# ===========

# %% [markdown]
# ### Check Available NDIF Remote Model

# %%
import nnsight

nnsight.ndif_status()
# Out:
# NDIF Service: Down 🔴
# Visit our community support at https://discuss.ndif.us/ or try again later.
# {}

# %% [markdown]
# ### Test Model outputs
#
# At a high level, there are 2 ways to run our model: using the `trace` method (a single forward pass) and the `generate` method (generating multiple tokens). We'll focus on `trace` for now, and we'll discuss `generate` when it comes to multi-token generation later.
#
# The default behaviour of forward passes in normal HuggingFace models is to return an object containing logits (and optionally a bunch of other things). The default behaviour of `trace` in `nnsight` is to not return anything, because anything that we choose to return is explicitly returned inside the context manager.
#
# Below is the simplest example of code to run the model (and also access the internal states of the model). Run it and look at the output, then read the explanation below. Remember to obtain and set an API key first if you're using remote execution!

# %%
# Gemma 3,NO REMOTE on NDIF
prompt = "The Eiffel Tower is in the city of"

with model.trace(prompt, remote=False):
    # Save the model's hidden states
    # Corrected attribute access: model.model.layers instead of model.transformer.h
    hidden_states = model.model.layers[-1].output[0].save() #(batch_size, seq_len, d_model)

    # Save the model's logit output
    # h.output[0].shape = (batch, seq, d_model)
    logits = model.lm_head.output[0, -1].save()

# Get the model's logit output, and it's next token prediction
print(f"logits.shape = {logits.shape} = (vocab_size,)")
print("Predicted token ID =", predicted_token_id := logits.argmax().item())
print(f"Predicted token = {tokenizer.decode(predicted_token_id)!r}")

# Print the shape of the model's residual stream
print(f"\nresid.shape = {hidden_states.shape} = (batch_size, seq_len, d_model)")
# Out:
# logits.shape = torch.Size([262144]) = (vocab_size,)
# Predicted token ID = 9079
# Predicted token = ' Paris'
#
# resid.shape = torch.Size([1, 9, 1152]) = (batch_size, seq_len, d_model)

# %% [markdown]
# ### Load SAE utilities

# %%
# Load SAE utilities
from sae_lens import SAE
from sae_lens.loading.pretrained_saes_directory import get_pretrained_saes_directory

# Example: list firsst 3 available SAE releases
sae_dir = get_pretrained_saes_directory()
sae_df = pd.DataFrame.from_records({k: v.__dict__ for k, v in sae_dir.items()}).T

display(sae_df.head(3))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 3
#       1 # Load SAE utilities
#       2 from sae_lens import SAE
# ----> 3 from sae_lens.loading.pretrained_saes_directory import get_pretrained_saes_directory
#       5 # Example: list firsst 3 available SAE releases
#       6 sae_dir = get_pretrained_saes_directory()
#
# ModuleNotFoundError: No module named 'sae_lens.loading'

# %%
# Get a Series of unique model names as a pandas Series
unique_models_series = pd.Series(sae_df['model'].unique())
print("\nUnique Model Names available on SAE_lens:\n", unique_models_series.to_string())
# Out:
# Unique Model Names available on SAE_lens:
#  0     deepseek-ai/DeepSeek-R1-Distill-Llama-8B
# 1                                   gemma-2-2b
# 2                                   gemma-2-9b
# 3                                  gemma-2b-it
# 4                                     gemma-2b
# 5                         google/gemma-3-1b-pt
# 6                        google/gemma-3-12b-it
# 7                        google/gemma-3-12b-pt
# 8                         google/gemma-3-1b-it
# 9                       google/gemma-3-270m-it
# 10                         google/gemma-3-270m
# 11                       google/gemma-3-27b-it
# 12                       google/gemma-3-27b-pt
# 13                        google/gemma-3-4b-it
# 14                        google/gemma-3-4b-pt
# 15                                 gemma-2-27b
# 16                               gemma-2-9b-it
# 17            meta-llama/Llama-3.1-8B-Instruct
# 18           meta-llama/Llama-3.3-70B-Instruct
# 19                          openai/gpt-oss-20b
# 20                                  gpt2-small
# 21         meta-llama/Meta-Llama-3-8B-Instruct
# 22                     meta-llama/Llama-3.1-8B
# 23                                  mistral-7b
# 24                                  qwen3-0.6b
# 25                                  qwen3-1.7b
# 26                                   qwen3-14b
# 27                                    qwen3-4b
# 28                                    qwen3-8b
# 29                          pythia-70m-deduped
# 30                    Qwen/Qwen2.5-7B-Instruct

# %%
# Filter to only show entries containing 'gemma' in the release name
gemma_saes = sae_df[sae_df['model'].str.contains('gemma', case=False, na=False)]
display(gemma_saes[['release','model']].head(40))
# Out:
#                                                                    release  \
# gemma-2-2b-res-matryoshka-dc                  gemma-2-2b-res-matryoshka-dc
# gemma-2-2b-res-snap-matryoshka-dc        gemma-2-2b-res-snap-matryoshka-dc
# gemma-2-9b-res-matryoshka-dc                  gemma-2-9b-res-matryoshka-dc
# gemma-2b-it-res-jb                                      gemma-2b-it-res-jb
# gemma-2b-res-jb                                            gemma-2b-res-jb
# gemma-3-1b-res-matryoshka-dc                  gemma-3-1b-res-matryoshka-dc
# gemma-scope-2-12b-it-att                          gemma-scope-2-12b-it-att
# gemma-scope-2-12b-it-att-all                  gemma-scope-2-12b-it-att-all
# gemma-scope-2-12b-it-mlp                          gemma-scope-2-12b-it-mlp
# gemma-scope-2-12b-it-mlp-all                  gemma-scope-2-12b-it-mlp-all
# gemma-scope-2-12b-it-res                          gemma-scope-2-12b-it-res
# gemma-scope-2-12b-it-res-all                  gemma-scope-2-12b-it-res-all
# gemma-scope-2-12b-it-transcoders          gemma-scope-2-12b-it-transcoders
# gemma-scope-2-12b-it-transcoders-all  gemma-scope-2-12b-it-transcoders-all
# gemma-scope-2-12b-pt-att                          gemma-scope-2-12b-pt-att
# gemma-scope-2-12b-pt-att-all                  gemma-scope-2-12b-pt-att-all
# gemma-scope-2-12b-pt-mlp                          gemma-scope-2-12b-pt-mlp
# gemma-scope-2-12b-pt-mlp-all                  gemma-scope-2-12b-pt-mlp-all
# gemma-scope-2-12b-pt-res                          gemma-scope-2-12b-pt-res
# gemma-scope-2-12b-pt-res-all                  gemma-scope-2-12b-pt-res-all
# gemma-scope-2-12b-pt-transcoders          gemma-scope-2-12b-pt-transcoders
# gemma-scope-2-12b-pt-transcoders-all  gemma-scope-2-12b-pt-transcoders-all
# gemma-scope-2-1b-it-att                            gemma-scope-2-1b-it-att
# gemma-scope-2-1b-it-att-all                    gemma-scope-2-1b-it-att-all
# gemma-scope-2-1b-it-mlp                            gemma-scope-2-1b-it-mlp
# gemma-scope-2-1b-it-mlp-all                    gemma-scope-2-1b-it-mlp-all
# gemma-scope-2-1b-it-res                            gemma-scope-2-1b-it-res
# gemma-scope-2-1b-it-res-all                    gemma-scope-2-1b-it-res-all
# gemma-scope-2-1b-it-transcoders            gemma-scope-2-1b-it-transcoders
# gemma-scope-2-1b-it-transcoders-all    gemma-scope-2-1b-it-transcoders-all
# gemma-scope-2-1b-pt-att                            gemma-scope-2-1b-pt-att
# gemma-scope-2-1b-pt-att-all                    gemma-scope-2-1b-pt-att-all
# gemma-scope-2-1b-pt-mlp                            gemma-scope-2-1b-pt-mlp
# gemma-scope-2-1b-pt-mlp-all                    gemma-scope-2-1b-pt-mlp-all
# gemma-scope-2-1b-pt-res                            gemma-scope-2-1b-pt-res
# gemma-scope-2-1b-pt-res-all                    gemma-scope-2-1b-pt-res-all
# gemma-scope-2-1b-pt-transcoders            gemma-scope-2-1b-pt-transcoders
# gemma-scope-2-1b-pt-transcoders-all    gemma-scope-2-1b-pt-transcoders-all
# gemma-scope-2-270m-it-att                        gemma-scope-2-270m-it-att
# gemma-scope-2-270m-it-att-all                gemma-scope-2-270m-it-att-all
#
#                                                        model
# gemma-2-2b-res-matryoshka-dc                      gemma-2-2b
# gemma-2-2b-res-snap-matryoshka-dc                 gemma-2-2b
# gemma-2-9b-res-matryoshka-dc                      gemma-2-9b
# gemma-2b-it-res-jb                               gemma-2b-it
# gemma-2b-res-jb                                     gemma-2b
# gemma-3-1b-res-matryoshka-dc            google/gemma-3-1b-pt
# gemma-scope-2-12b-it-att               google/gemma-3-12b-it
# gemma-scope-2-12b-it-att-all           google/gemma-3-12b-it
# gemma-scope-2-12b-it-mlp               google/gemma-3-12b-it
# gemma-scope-2-12b-it-mlp-all           google/gemma-3-12b-it
# gemma-scope-2-12b-it-res               google/gemma-3-12b-it
# gemma-scope-2-12b-it-res-all           google/gemma-3-12b-it
# gemma-scope-2-12b-it-transcoders       google/gemma-3-12b-it
# gemma-scope-2-12b-it-transcoders-all   google/gemma-3-12b-it
# gemma-scope-2-12b-pt-att               google/gemma-3-12b-pt
# gemma-scope-2-12b-pt-att-all           google/gemma-3-12b-pt
# gemma-scope-2-12b-pt-mlp               google/gemma-3-12b-pt
# gemma-scope-2-12b-pt-mlp-all           google/gemma-3-12b-pt
# gemma-scope-2-12b-pt-res               google/gemma-3-12b-pt
# gemma-scope-2-12b-pt-res-all           google/gemma-3-12b-pt
# gemma-scope-2-12b-pt-transcoders       google/gemma-3-12b-pt
# gemma-scope-2-12b-pt-transcoders-all   google/gemma-3-12b-pt
# gemma-scope-2-1b-it-att                 google/gemma-3-1b-it
# gemma-scope-2-1b-it-att-all             google/gemma-3-1b-it
# gemma-scope-2-1b-it-mlp                 google/gemma-3-1b-it
# gemma-scope-2-1b-it-mlp-all             google/gemma-3-1b-it
# gemma-scope-2-1b-it-res                 google/gemma-3-1b-it
# gemma-scope-2-1b-it-res-all             google/gemma-3-1b-it
# gemma-scope-2-1b-it-transcoders         google/gemma-3-1b-it
# gemma-scope-2-1b-it-transcoders-all     google/gemma-3-1b-it
# gemma-scope-2-1b-pt-att                 google/gemma-3-1b-pt
# gemma-scope-2-1b-pt-att-all             google/gemma-3-1b-pt
# gemma-scope-2-1b-pt-mlp                 google/gemma-3-1b-pt
# gemma-scope-2-1b-pt-mlp-all             google/gemma-3-1b-pt
# gemma-scope-2-1b-pt-res                 google/gemma-3-1b-pt
# gemma-scope-2-1b-pt-res-all             google/gemma-3-1b-pt
# gemma-scope-2-1b-pt-transcoders         google/gemma-3-1b-pt
# gemma-scope-2-1b-pt-transcoders-all     google/gemma-3-1b-pt
# gemma-scope-2-270m-it-att             google/gemma-3-270m-it
# gemma-scope-2-270m-it-att-all         google/gemma-3-270m-it

# %% [markdown]
# ### Load a specific SAE
# (pick the hook point you want, e.g., a residual stream SAE)
# SAE lens sample :
# https://decoderesearch.github.io/SAELens/latest/usage/

# %%
# Load a specific SAE (pick the hook point you want, e.g., a residual stream SAE)
# Format for loading SAE :
#   https://decoderesearch.github.io/SAELens/latest/#loading-sparse-autoencoders-from-huggingface
#   https://decoderesearch.github.io/SAELens/latest/usage/
# Availble SAEs:
#   https://huggingface.co/models?library=saelens

release = "gemma-scope-2-1b-it-res"
LAYER = 22  # options are {7, 13, 17, 22}
WIDTH = "65k"   # options are {16k, 65k, 262k, 1m}
L0 = "medium"  # options are {small, medium, big}
sae_id = f"layer_{LAYER}_width_{WIDTH}_l0_{L0}"

sae, cfg_dict, sparsity = SAE.from_pretrained_with_cfg_and_sparsity(
    release = release,
    sae_id = sae_id,
    device = "cpu", # Load to CPU first to avoid SafetensorError
)

print("="*3, "Loaded SAE for hook","="*3)
print(f"{release}/{sae_id}")
print(f"Layer: {LAYER}")
print(f"Width: {WIDTH}")
print(f"L0: {L0}")
print("="*25)

# ====== Key SAE Attributes ======
# Model dimensions
print("\n> Model dimensions")
print(f"Input dimension (d_in): {sae.cfg.d_in}")
print(f"SAE dimension (d_sae): {sae.cfg.d_sae}")
print(f"Expansion factor: {sae.cfg.d_sae / sae.cfg.d_in}")

# Metadata about the SAE
print("\n> SAE metadata")
print(f"Hook name: {sae.cfg.metadata.hook_name}")
print(f"Model name: {sae.cfg.metadata.model_name}")
print(f"Context size: {sae.cfg.metadata.context_size}")

# Hugging Face / NNsight Hook Name (if present)
print("\n> Hugging Face / NNsight Hook Name (if present)")
print(f"Hook name: {sae.cfg.metadata.hf_hook_name}")

# Weights
print("\n> Weight")
print(f"Encoder weights shape: {sae.W_enc.shape}")  # (d_in, d_sae)
print(f"Decoder weights shape: {sae.W_dec.shape}")  # (d_sae, d_in)
print(f"Decoder bias shape: {sae.b_dec.shape}")     # (d_in,)

print()
print("== SAE cfg ==\n")
sae.to(device) # Then move the SAE to the actual device (CUDA in this case)
# Out:
# === Loaded SAE for hook ===
# gemma-scope-2-1b-it-res/layer_22_width_65k_l0_medium
# Layer: 22
# Width: 65k
# L0: medium
# =========================
#
# > Model dimensions
# Input dimension (d_in): 1152
# SAE dimension (d_sae): 65536
# Expansion factor: 56.888888888888886
#
# > SAE metadata
# Hook name: blocks.22.hook_resid_post
# Model name: google/gemma-3-1b-it
# Context size: 1024
#
# > Hugging Face / NNsight Hook Name (if present)
# Hook name: model.layers.22.output
#
# > Weight
# Encoder weights shape: torch.Size([1152, 65536])
# Decoder weights shape: torch.Size([65536, 1152])
# Decoder bias shape: torch.Size([1152])
#
# == SAE cfg ==
# JumpReLUSAE(
#   (activation_fn): ReLU()
#   (hook_sae_input): HookPoint()
#   (hook_sae_acts_pre): HookPoint()
#   (hook_sae_acts_post): HookPoint()
#   (hook_sae_output): HookPoint()
#   (hook_sae_recons): HookPoint()
#   (hook_sae_error): HookPoint()
# )

# %% [markdown]
# Using SAEs with NNsight
# nnsight provides a clean interface for model interventions. SAEs integrate naturally with nnsight's tracing API.

# %%
prompt = "The Eiffel Tower is located in"

# Extract activations and compute SAE features
with model.trace(prompt):
    # .output[0] is the hidden states
    # .output[1] is the key-value caches ((key_states, value_states) tuple)
    # Access hidden states at layer
    hidden_states = model.model.layers[22].output[0]

    # Save the hidden states
    hidden_states_saved = hidden_states.save()

# Get SAE features outside the trace
with torch.no_grad():
    features = sae.encode(hidden_states_saved)

print(f"Feature activations shape: {features.shape}")
print(f"Average L0: {(features[:, 1:, :] > 0).sum(dim=-1).float().mean().item():.1f}")
# Out:
# Feature activations shape: torch.Size([1, 7, 65536])
# Average L0: 979.2

# %%
# features shape: (batch_size, seq_len, d_sae)
values, indexs = features[0].mean(0).topk(10)
for value, index in zip(values,indexs):
  print(f"{value:>6.1f}|{index}")

# see SAE Tutorial
# Out:
# 1721.7|1217
# 1637.9|1904
# 1589.6|1497
# 1427.6|1503
# 1409.6|908
# 1274.7|1169
# 1236.8|121
# 1090.6|94
# 1027.1|65093
# 1004.1|613

# %%
feature_idx = 18126

str_toks = tokenizer.tokenize(prompt, add_special_tokens=True)
activations = features[0, :, feature_idx].tolist()

def html_activations(str_toks: list[str], activations: list[float]):
  max_activation = np.max(activations)
  return "".join(
      f'<span style="background-color: rgba(255,0,0,{v}); padding: 4px 0px;">{t}</span>'
      for t, v in zip(str_toks, np.array(activations) / (1e-6 + max_activation), strict=True)
  )

display(HTML(html_activations(str_toks, activations)))
# Out:
# <span style="background-color: rgba(255,0,0,0.0); padding: 4px 0px;"><bos></span><span style="background-color: rgba(255,0,0,0.0); padding: 4px 0px;">The</span><span style="background-color: rgba(255,0,0,0.35641075074676154); padding: 4px 0px;">▁Eiffel</span><span style="background-color: rgba(255,0,0,0.0); padding: 4px 0px;">▁Tower</span><span style="background-color: rgba(255,0,0,0.0); padding: 4px 0px;">▁is</span><span style="background-color: rgba(255,0,0,0.21678431945486973); padding: 4px 0px;">▁located</span><span style="background-color: rgba(255,0,0,0.9999999995792744); padding: 4px 0px;">▁in</span>

# %%
from IPython.display import IFrame

# get a random feature from the SAE
feature_idx = torch.randint(0, sae.cfg.d_sae, (1,)).item()
feature_idx = 18126

# Home/Gemma-3-1B-IT/7-GEMMASCOPE-2-RES-262K/8229, feature: "unable"

MODEL = "gemma-3-1b-it"
neuropedia_saeid = f"{LAYER}-gemmascope-2-res-{WIDTH}"
html_template = F"https://neuronpedia.org/{MODEL}/{neuropedia_saeid}/{feature_idx}?embed=true&embedexplanation=true&embedplots=true&embedtest=true&height=300"

def get_dashboard_html(sae_release=release, sae_id=sae_id, feature_idx=0):
    return html_template.format(sae_release, sae_id, feature_idx)


html = get_dashboard_html(
    sae_release=release, sae_id=sae_id, feature_idx=1000
)
IFrame(html, width=1200, height=600)
# Out:
#         <iframe
#             width="1200"
#             height="600"
#             src="https://neuronpedia.org/gemma-3-1b-it/22-gemmascope-2-res-65k/18126?embed=true&embedexplanation=true&embedplots=true&embedtest=true&height=300"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from datasets import load_dataset
from transformer_lens import HookedTransformer
from sae_lens import SAE
from transformers import AutoModelForCausalLM
from huggingface_hub import login



from transformer_lens.utils import tokenize_and_concatenate

dataset = load_dataset(
    path="NeelNanda/pile-10k",
    split="train",
    streaming=False,
)

dataset = dataset.select(range(256))

token_dataset = tokenize_and_concatenate(
    dataset=dataset,  # type: ignore
    tokenizer=model.tokenizer,  # type: ignore
    streaming=True,
    max_length=128,
    add_bos_token=sae.cfg.metadata.prepend_bos,
)
# Out:
# [autoreload of datasets.features.nifti failed: Traceback (most recent call last):
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\importlib\__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 860, in _exec
#   File "<frozen importlib._bootstrap_external>", line 994, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\datasets\features\nifti.py", line 20, in <module>
#     if config.NIBABEL_AVAILABLE:
#        ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'datasets.config' has no attribute 'NIBABEL_AVAILABLE'. Did you mean: 'PIL_AVAILABLE'?
# ]
# [autoreload of datasets.packaged_modules.eval.eval failed: Traceback (most recent call last):
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\importlib\__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 860, in _exec
#   File "<frozen importlib._bootstrap_external>", line 994, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\datasets\packaged_modules\eval\eval.py", line 9, in <module>
#     from datasets.builder import Key
# ImportError: cannot import name 'Key' from 'datasets.builder' (c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\datasets\builder.py)
# ]
# [autoreload of datasets.packaged_modules.hdf5.hdf5 failed: Traceback (most recent call last):
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\importlib\__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 860, in _exec
#   File "<frozen importlib._bootstrap_external>", line 994, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\datasets\packaged_modules\hdf5\hdf5.py", line 8, in <module>
#     from datasets.builder import Key
# ImportError: cannot import name 'Key' from 'datasets.builder' (c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\datasets\builder.py)
# ]
# [autoreload of datasets.packaged_modules.lance.lance failed: Traceback (most recent call last):
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\importlib\__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 860, in _exec
#   File "<frozen importlib._bootstrap_external>", line 994, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\datasets\packaged_modules\lance\lance.py", line 10, in <module>
#     from datasets.builder import Key
# ImportError: cannot import name 'Key' from 'datasets.builder' (c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\datasets\builder.py)
# ]
# [autoreload of datasets.packaged_modules.niftifolder.niftifolder failed: Traceback (most recent call last):
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\importlib\__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 860, in _exec
#   File "<frozen importlib._bootstrap_external>", line 994, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\datasets\packaged_modules\niftifolder\niftifolder.py", line 6, in <module>
#     logger = datasets.utils.logging.get_logger(__name__)
#              ^^^^^^^^^^^^^^
# AttributeError: module 'datasets' has no attribute 'utils'
# ]
# [autoreload of datasets.packaged_modules.pdffolder.pdffolder failed: Traceback (most recent call last):
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\importlib\__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 860, in _exec
#   File "<frozen importlib._bootstrap_external>", line 994, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\datasets\packaged_modules\pdffolder\pdffolder.py", line 6, in <module>
#     logger = datasets.utils.logging.get_logger(__name__)
#              ^^^^^^^^^^^^^^
# AttributeError: module 'datasets' has no attribute 'utils'
# ]
# [autoreload of datasets.packaged_modules.videofolder.videofolder failed: Traceback (most recent call last):
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\importlib\__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 860, in _exec
#   File "<frozen importlib._bootstrap_external>", line 994, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\datasets\packaged_modules\videofolder\videofolder.py", line 6, in <module>
#     logger = datasets.utils.logging.get_logger(__name__)
#              ^^^^^^^^^^^^^^
# AttributeError: module 'datasets' has no attribute 'utils'
# ]
# [autoreload of datasets.packaged_modules.xml.xml failed: Traceback (most recent call last):
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\importlib\__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 860, in _exec
#   File "<frozen importlib._bootstrap_external>", line 994, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\datasets\packaged_modules\xml\xml.py", line 11, in <module>
#     logger = datasets.utils.logging.get_logger(__name__)
#              ^^^^^^^^^^^^^^
# AttributeError: module 'datasets' has no attribute 'utils'
# ]
# [autoreload of datasets.utils.deprecation_utils failed: Traceback (most recent call last):
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 621, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 447, in update_generic
#     update(a, b)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 415, in update_class
#     update_instances(old, new)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 373, in update_instances
#     object.__setattr__(ref, "__class__", new)
# TypeError: can't apply this __setattr__ to OnAccess object
# ]
# [autoreload of datasets.features.features failed: Traceback (most recent call last):
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\importlib\__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 860, in _exec
#   File "<frozen importlib._bootstrap_external>", line 994, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\datasets\features\features.py", line 749, in <module>
#     pa.register_extension_type(Array2DExtensionType((1, 2), "int64"))
#   File "pyarrow/types.pxi", line 2226, in pyarrow.lib.register_extension_type
#   File "pyarrow/error.pxi", line 92, in pyarrow.lib.check_status
# pyarrow.lib.ArrowKeyError: A type extension with name datasets.features.features.Array2DExtensionType already defined
# ]
# [autoreload of datasets.splits failed: Traceback (most recent call last):
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 621, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 447, in update_generic
#     update(a, b)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 415, in update_class
#     update_instances(old, new)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 373, in update_instances
#     object.__setattr__(ref, "__class__", new)
# TypeError: can't apply this __setattr__ to PercentSliceMeta object
# ]
# [autoreload of datasets.iterable_dataset failed: Traceback (most recent call last):
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 621, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 447, in update_generic
#     update(a, b)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 399, in update_class
#     if update_generic(old_obj, new_obj):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 447, in update_generic
#     update(a, b)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 359, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: _iter() requires a code object with 0 free vars, not 1971389988865
# ]
# [autoreload of datasets.packaged_modules.folder_based_builder.folder_based_builder failed: Traceback (most recent call last):
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\importlib\__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 860, in _exec
#   File "<frozen importlib._bootstrap_external>", line 994, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\datasets\packaged_modules\folder_based_builder\folder_based_builder.py", line 21, in <module>
#     logger = datasets.utils.logging.get_logger(__name__)
#              ^^^^^^^^^^^^^^
# AttributeError: module 'datasets' has no attribute 'utils'
# ]
# [autoreload of datasets.packaged_modules.audiofolder.audiofolder failed: Traceback (most recent call last):
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\importlib\__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 860, in _exec
#   File "<frozen importlib._bootstrap_external>", line 994, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\datasets\packaged_modules\audiofolder\audiofolder.py", line 6, in <module>
#     logger = datasets.utils.logging.get_logger(__name__)
#              ^^^^^^^^^^^^^^
# AttributeError: module 'datasets' has no attribute 'utils'
# ]
# [autoreload of datasets.packaged_modules.cache.cache failed: Traceback (most recent call last):
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\importlib\__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 860, in _exec
#   File "<frozen importlib._bootstrap_external>", line 994, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\datasets\packaged_modules\cache\cache.py", line 18, in <module>
#     logger = datasets.utils.logging.get_logger(__name__)
#              ^^^^^^^^^^^^^^
# AttributeError: module 'datasets' has no attribute 'utils'
# ]
# [autoreload of datasets.packaged_modules.imagefolder.imagefolder failed: Traceback (most recent call last):
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\importlib\__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 860, in _exec
#   File "<frozen importlib._bootstrap_external>", line 994, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\datasets\packaged_modules\imagefolder\imagefolder.py", line 6, in <module>
#     logger = datasets.utils.logging.get_logger(__name__)
#              ^^^^^^^^^^^^^^
# AttributeError: module 'datasets' has no attribute 'utils'
# ]
# [autoreload of datasets.packaged_modules.webdataset.webdataset failed: Traceback (most recent call last):
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\importlib\__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 860, in _exec
#   File "<frozen importlib._bootstrap_external>", line 994, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\datasets\packaged_modules\webdataset\webdataset.py", line 17, in <module>
#     logger = datasets.utils.logging.get_logger(__name__)
#              ^^^^^^^^^^^^^^
# AttributeError: module 'datasets' has no attribute 'utils'
# ]
# README.md:   0%|          | 0.00/373 [00:00<?, ?B/s]
# c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Lab622_TV\.cache\huggingface\hub\datasets--NeelNanda--pile-10k. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 11
#       5 from huggingface_hub import login
#       9 from transformer_lens.utils import tokenize_and_concatenate
# ---> 11 dataset = load_dataset(
#      12     path="NeelNanda/pile-10k",
#      13     split="train",
#      14     streaming=False,
#      15 )
#      17 dataset = dataset.select(range(256))
#      19 token_dataset = tokenize_and_concatenate(
#      20     dataset=dataset,  # type: ignore
#      21     tokenizer=model.tokenizer,  # type: ignore
#    (...)     24     add_bos_token=sae.cfg.metadata.prepend_bos,
#      25 )
#
# File c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\datasets\load.py:1488, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1483 verification_mode = VerificationMode(
#    1484     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    1485 )
#    1487 # Create a dataset builder
# -> 1488 builder_instance = load_dataset_builder(
#    1489     path=path,
#    1490     name=name,
#    1491     data_dir=data_dir,
#    1492     data_files=data_files,
#    1493     cache_dir=cache_dir,
#    1494     features=features,
#    1495     download_config=download_config,
#    1496     download_mode=download_mode,
#    1497     revision=revision,
#    1498     token=token,
#    1499     storage_options=storage_options,
#    1500     **config_kwargs,
#    1501 )
#    1503 # Return iterable dataset in case of streaming
#    1504 if streaming:
#
# File c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\datasets\load.py:1133, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, storage_options, **config_kwargs)
#    1131 if features is not None:
#    1132     features = _fix_for_backward_compatible_features(features)
# -> 1133 dataset_module = dataset_module_factory(
#    1134     path,
#    1135     revision=revision,
#    1136     download_config=download_config,
#    1137     download_mode=download_mode,
#    1138     data_dir=data_dir,
#    1139     data_files=data_files,
#    1140     cache_dir=cache_dir,
#    1141 )
#    1142 # Get dataset builder class
#    1143 builder_kwargs = dataset_module.builder_kwargs
#
# File c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\datasets\load.py:1032, in dataset_module_factory(path, revision, download_config, download_mode, data_dir, data_files, cache_dir, **download_kwargs)
#    1027             if isinstance(e1, FileNotFoundError):
#    1028                 raise FileNotFoundError(
#    1029                     f"Couldn't find any data file at {relative_to_absolute_path(path)}. "
#    1030                     f"Couldn't find '{path}' on the Hugging Face Hub either: {type(e1).__name__}: {e1}"
#    1031                 ) from None
# -> 1032             raise e1 from None
#    1033 else:
#    1034     raise FileNotFoundError(f"Couldn't find any data file at {relative_to_absolute_path(path)}.")
#
# File c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\datasets\load.py:1007, in dataset_module_factory(path, revision, download_config, download_mode, data_dir, data_files, cache_dir, **download_kwargs)
#     997     else:
#     998         use_exported_dataset_infos = True
#     999     return HubDatasetModuleFactory(
#    1000         path,
#    1001         commit_hash=commit_hash,
#    1002         data_dir=data_dir,
#    1003         data_files=data_files,
#    1004         download_config=download_config,
#    1005         download_mode=download_mode,
#    1006         use_exported_dataset_infos=use_exported_dataset_infos,
# -> 1007     ).get_module()
#    1008 except GatedRepoError as e:
#    1009     message = f"Dataset '{path}' is a gated dataset on the Hub."
#
# File c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\datasets\load.py:660, in HubDatasetModuleFactory.get_module(self)
#     651     builder_configs, default_config_name = create_builder_configs_from_metadata_configs(
#     652         module_path,
#     653         metadata_configs,
#    (...)    656         download_config=self.download_config,
#     657     )
#     658 else:
#     659     builder_configs: list[BuilderConfig] = [
# --> 660         import_main_class(module_path).BUILDER_CONFIG_CLASS(
#     661             data_files=data_files,
#     662             **default_builder_kwargs,
#     663         )
#     664     ]
#     665     default_config_name = None
#     666 builder_kwargs = {
#     667     "base_path": hf_dataset_url(self.name, "", revision=self.commit_hash).rstrip("/"),
#     668     "repo_id": self.name,
#     669     "dataset_name": camelcase_to_snakecase(Path(self.name).name),
#     670 }
#
# AttributeError: 'NoneType' object has no attribute 'BUILDER_CONFIG_CLASS'

# %%
from sae_dashboard.sae_vis_data import SaeVisConfig
from sae_dashboard.sae_vis_runner import SaeVisRunner
import random

# generate a list of 10 random features between 0 and 65k
test_feature_idx_gpt = random.sample(range(65536), 10)
hook_name = sae.cfg.metadata.hf_hook_name
print(f"Hook name: {hook_name}")

feature_vis_config_gpt = SaeVisConfig(
    hook_point=hook_name,
    features=test_feature_idx_gpt,
    minibatch_size_features=64,
    minibatch_size_tokens=256,
    verbose=True,
    device=device,
)

visualization_data_gpt = SaeVisRunner(
    feature_vis_config_gpt
).run(
    encoder=sae,  # type: ignore
    model=model,
    tokens=token_dataset[:256]["tokens"],  # type: ignore
)
# SaeVisData.create(
#     encoder=sae,
#     model=model, # type: ignore
#     tokens=token_dataset[:10000]["tokens"],  # type: ignore
#     cfg=feature_vis_config_gpt,
# )
# Out:
# Hook name: model.layers.22.output
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 24
#       8 print(f"Hook name: {hook_name}")
#      10 feature_vis_config_gpt = SaeVisConfig(
#      11     hook_point=hook_name,
#      12     features=test_feature_idx_gpt,
#    (...)     16     device=device,
#      17 )
#      19 visualization_data_gpt = SaeVisRunner(
#      20     feature_vis_config_gpt
#      21 ).run(
#      22     encoder=sae,  # type: ignore
#      23     model=model,
# ---> 24     tokens=token_dataset[:256]["tokens"],  # type: ignore
#      25 )
#      26 # SaeVisData.create(
#      27 #     encoder=sae,
#      28 #     model=model, # type: ignore
#      29 #     tokens=token_dataset[:10000]["tokens"],  # type: ignore
#      30 #     cfg=feature_vis_config_gpt,
#      31 # )
#
# KeyError: slice(None, 256, None)

# %%
# !pip install sae-dashboard
# Out:
# c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\datasets\filesystems\__init__.py:30: UserWarning: A filesystem protocol was already set for bz2 and will be overwritten.
#   warnings.warn(f"A filesystem protocol was already set for {fs_class.protocol} and will be overwritten.")
# c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\datasets\filesystems\__init__.py:30: UserWarning: A filesystem protocol was already set for gzip and will be overwritten.
#   warnings.warn(f"A filesystem protocol was already set for {fs_class.protocol} and will be overwritten.")
# c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\datasets\filesystems\__init__.py:30: UserWarning: A filesystem protocol was already set for lz4 and will be overwritten.
#   warnings.warn(f"A filesystem protocol was already set for {fs_class.protocol} and will be overwritten.")
# c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\datasets\filesystems\__init__.py:30: UserWarning: A filesystem protocol was already set for xz and will be overwritten.
#   warnings.warn(f"A filesystem protocol was already set for {fs_class.protocol} and will be overwritten.")
# c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\datasets\filesystems\__init__.py:30: UserWarning: A filesystem protocol was already set for zstd and will be overwritten.
#   warnings.warn(f"A filesystem protocol was already set for {fs_class.protocol} and will be overwritten.")
# [autoreload of datasets.features.features failed: Traceback (most recent call last):
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\importlib\__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 860, in _exec
#   File "<frozen importlib._bootstrap_external>", line 994, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\datasets\features\features.py", line 706, in <module>
#     pa.register_extension_type(Array2DExtensionType((1, 2), "int64"))
#   File "pyarrow/types.pxi", line 2226, in pyarrow.lib.register_extension_type
#   File "pyarrow/error.pxi", line 92, in pyarrow.lib.check_status
# pyarrow.lib.ArrowKeyError: A type extension with name datasets.features.features.Array2DExtensionType already defined
# ]
# [autoreload of datasets.splits failed: Traceback (most recent call last):
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 621, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 447, in update_generic
#     update(a, b)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 415, in update_class
#     update_instances(old, new)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 373, in update_instances
#     object.__setattr__(ref, "__class__", new)
# TypeError: can't apply this __setattr__ to PercentSliceMeta object
# ]
# [autoreload of datasets.arrow_writer failed: Traceback (most recent call last):
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 621, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 447, in update_generic
#     update(a, b)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 399, in update_class
#     if update_generic(old_obj, new_obj):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 447, in update_generic
#     update(a, b)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 359, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 1 free vars, not 1984274890752
# ]
# [autoreload of datasets.arrow_dataset failed: Traceback (most recent call last):
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 621, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 447, in update_generic
#     update(a, b)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 399, in update_class
#     if update_generic(old_obj, new_obj):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 447, in update_generic
#     update(a, b)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 359, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: rename_column() requires a code object with 7 free vars, not 1984274890753
# ]
# [autoreload of datasets.iterable_dataset failed: Traceback (most recent call last):
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 621, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 447, in update_generic
#     update(a, b)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 399, in update_class
#     if update_generic(old_obj, new_obj):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 447, in update_generic
#     update(a, b)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 359, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: _iter() requires a code object with 1 free vars, not 1984274890752
# ]
# [autoreload of datasets.packaged_modules.arrow.arrow failed: Traceback (most recent call last):
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\importlib\__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 860, in _exec
#   File "<frozen importlib._bootstrap_external>", line 994, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\datasets\packaged_modules\arrow\arrow.py", line 11, in <module>
#     logger = datasets.utils.logging.get_logger(__name__)
#              ^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'datasets.utils' has no attribute 'logging'
# ]
# [autoreload of datasets.packaged_modules.folder_based_builder.folder_based_builder failed: Traceback (most recent call last):
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\importlib\__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 860, in _exec
#   File "<frozen importlib._bootstrap_external>", line 994, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\datasets\packaged_modules\folder_based_builder\folder_based_builder.py", line 16, in <module>
#     logger = datasets.utils.logging.get_logger(__name__)
#              ^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'datasets.utils' has no attribute 'logging'
# ]
# [autoreload of datasets.packaged_modules.audiofolder.audiofolder failed: Traceback (most recent call last):
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\importlib\__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 860, in _exec
#   File "<frozen importlib._bootstrap_external>", line 994, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\datasets\packaged_modules\audiofolder\audiofolder.py", line 9, in <module>
#     logger = datasets.utils.logging.get_logger(__name__)
#              ^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'datasets.utils' has no attribute 'logging'
# ]
# [autoreload of datasets.packaged_modules.cache.cache failed: Traceback (most recent call last):
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\importlib\__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 860, in _exec
#   File "<frozen importlib._bootstrap_external>", line 994, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\datasets\packaged_modules\cache\cache.py", line 18, in <module>
#     logger = datasets.utils.logging.get_logger(__name__)
#              ^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'datasets.utils' has no attribute 'logging'
# ]
# [autoreload of datasets.packaged_modules.csv.csv failed: Traceback (most recent call last):
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\importlib\__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 860, in _exec
#   File "<frozen importlib._bootstrap_external>", line 994, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\datasets\packaged_modules\csv\csv.py", line 15, in <module>
#     logger = datasets.utils.logging.get_logger(__name__)
#              ^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'datasets.utils' has no attribute 'logging'
# ]
# [autoreload of datasets.packaged_modules.imagefolder.imagefolder failed: Traceback (most recent call last):
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\importlib\__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 860, in _exec
#   File "<frozen importlib._bootstrap_external>", line 994, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\datasets\packaged_modules\imagefolder\imagefolder.py", line 9, in <module>
#     logger = datasets.utils.logging.get_logger(__name__)
#              ^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'datasets.utils' has no attribute 'logging'
# ]
# [autoreload of datasets.packaged_modules.json.json failed: Traceback (most recent call last):
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\importlib\__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 860, in _exec
#   File "<frozen importlib._bootstrap_external>", line 994, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\datasets\packaged_modules\json\json.py", line 16, in <module>
#     logger = datasets.utils.logging.get_logger(__name__)
#              ^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'datasets.utils' has no attribute 'logging'
# ]
# [autoreload of datasets.packaged_modules.parquet.parquet failed: Traceback (most recent call last):
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\importlib\__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 860, in _exec
#   File "<frozen importlib._bootstrap_external>", line 994, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\datasets\packaged_modules\parquet\parquet.py", line 12, in <module>
#     logger = datasets.utils.logging.get_logger(__name__)
#              ^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'datasets.utils' has no attribute 'logging'
# ]
# [autoreload of datasets.packaged_modules.sql.sql failed: Traceback (most recent call last):
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\importlib\__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 860, in _exec
#   File "<frozen importlib._bootstrap_external>", line 994, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\datasets\packaged_modules\sql\sql.py", line 20, in <module>
#     logger = datasets.utils.logging.get_logger(__name__)
#              ^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'datasets.utils' has no attribute 'logging'
# ]
# [autoreload of datasets.packaged_modules.text.text failed: Traceback (most recent call last):
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\importlib\__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 860, in _exec
#   File "<frozen importlib._bootstrap_external>", line 994, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\datasets\packaged_modules\text\text.py", line 14, in <module>
#     logger = datasets.utils.logging.get_logger(__name__)
#              ^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'datasets.utils' has no attribute 'logging'
# ]
# [autoreload of datasets.packaged_modules.webdataset.webdataset failed: Traceback (most recent call last):
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\importlib\__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 860, in _exec
#   File "<frozen importlib._bootstrap_external>", line 994, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\datasets\packaged_modules\webdataset\webdataset.py", line 15, in <module>
#     logger = datasets.utils.logging.get_logger(__name__)
#              ^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'datasets.utils' has no attribute 'logging'
# ]
# [autoreload of sae_lens.analysis.hooked_sae_transformer failed: Traceback (most recent call last):
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\importlib\__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 860, in _exec
#   File "<frozen importlib._bootstrap_external>", line 994, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\sae_lens\analysis\hooked_sae_transformer.py", line 11, in <module>
#     from sae_lens.sae import SAE
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\sae_lens\sae.py", line 20, in <module>
#     from sae_lens.config import (
# ImportError: cannot import name 'SAE_CFG_FILENAME' from 'sae_lens.config' (c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\sae_lens\config.py)
# ]
# [autoreload of sae_lens.config failed: Traceback (most recent call last):
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 621, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 447, in update_generic
#     update(a, b)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 399, in update_class
#     if update_generic(old_obj, new_obj):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 447, in update_generic
#     update(a, b)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 359, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 5 free vars, not 1988569858052
# ]
# [autoreload of sae_lens.load_model failed: Traceback (most recent call last):
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 621, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 447, in update_generic
#     update(a, b)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 399, in update_class
#     if update_generic(old_obj, new_obj):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 447, in update_generic
#     update(a, b)
#   File "c:\Users\Lab622_TV\miniforge3\envs\MI\Lib\site-packages\IPython\extensions\autoreload.py", line 359, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: run_with_cache() requires a code object with 1 free vars, not 1971389988864
# ]
# Requirement already satisfied: sae-dashboard in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (0.6.11)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.4 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from sae-dashboard) (0.6.7)
# Requirement already satisfied: datasets<3.0.0,>=2.0.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from sae-dashboard) (2.21.0)
# Requirement already satisfied: eindex-callum<0.2.0,>=0.1.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from sae-dashboard) (0.1.2)
# Requirement already satisfied: einops>=0.7.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from sae-dashboard) (0.7.0)
# Requirement already satisfied: jaxtyping<0.3.0,>=0.2.28 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from sae-dashboard) (0.2.38)
# Requirement already satisfied: matplotlib<4.0.0,>=3.8.4 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from sae-dashboard) (3.10.8)
# Requirement already satisfied: rich<14.0.0,>=13.7.1 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from sae-dashboard) (13.9.4)
# Requirement already satisfied: sae-lens<6.0.0,>=5.0.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from sae-dashboard) (5.11.0)
# Requirement already satisfied: safetensors<0.5.0,>=0.4.3 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from sae-dashboard) (0.4.5)
# Requirement already satisfied: torch<3.0.0,>=2.0.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from sae-dashboard) (2.9.1+cu130)
# Requirement already satisfied: transformer-lens<3.0.0,>=2.2.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from sae-dashboard) (2.16.1)
# Requirement already satisfied: typer<0.13.0,>=0.12.3 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from sae-dashboard) (0.12.5)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.4->sae-dashboard) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.4->sae-dashboard) (0.9.0)
# Requirement already satisfied: filelock in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from datasets<3.0.0,>=2.0.0->sae-dashboard) (3.20.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from datasets<3.0.0,>=2.0.0->sae-dashboard) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from datasets<3.0.0,>=2.0.0->sae-dashboard) (22.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from datasets<3.0.0,>=2.0.0->sae-dashboard) (0.3.8)
# Requirement already satisfied: pandas in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from datasets<3.0.0,>=2.0.0->sae-dashboard) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from datasets<3.0.0,>=2.0.0->sae-dashboard) (2.32.5)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from datasets<3.0.0,>=2.0.0->sae-dashboard) (4.67.1)
# Requirement already satisfied: xxhash in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from datasets<3.0.0,>=2.0.0->sae-dashboard) (3.6.0)
# Requirement already satisfied: multiprocess in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from datasets<3.0.0,>=2.0.0->sae-dashboard) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets<3.0.0,>=2.0.0->sae-dashboard) (2024.6.1)
# Requirement already satisfied: aiohttp in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from datasets<3.0.0,>=2.0.0->sae-dashboard) (3.13.3)
# Requirement already satisfied: huggingface-hub>=0.21.2 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from datasets<3.0.0,>=2.0.0->sae-dashboard) (0.36.0)
# Requirement already satisfied: packaging in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from datasets<3.0.0,>=2.0.0->sae-dashboard) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from datasets<3.0.0,>=2.0.0->sae-dashboard) (6.0.3)
# Requirement already satisfied: wadler-lindig>=0.1.3 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from jaxtyping<0.3.0,>=0.2.28->sae-dashboard) (0.1.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from matplotlib<4.0.0,>=3.8.4->sae-dashboard) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from matplotlib<4.0.0,>=3.8.4->sae-dashboard) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from matplotlib<4.0.0,>=3.8.4->sae-dashboard) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from matplotlib<4.0.0,>=3.8.4->sae-dashboard) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from matplotlib<4.0.0,>=3.8.4->sae-dashboard) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from matplotlib<4.0.0,>=3.8.4->sae-dashboard) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from matplotlib<4.0.0,>=3.8.4->sae-dashboard) (2.9.0.post0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from rich<14.0.0,>=13.7.1->sae-dashboard) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from rich<14.0.0,>=13.7.1->sae-dashboard) (2.19.2)
# Requirement already satisfied: automated-interpretability<1.0.0,>=0.0.5 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from sae-lens<6.0.0,>=5.0.0->sae-dashboard) (0.0.18)
# Requirement already satisfied: babe<0.0.8,>=0.0.7 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from sae-lens<6.0.0,>=5.0.0->sae-dashboard) (0.0.7)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.6 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from sae-lens<6.0.0,>=5.0.0->sae-dashboard) (0.1.7)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from sae-lens<6.0.0,>=5.0.0->sae-dashboard) (3.9.2)
# Requirement already satisfied: plotly<6.0.0,>=5.19.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from sae-lens<6.0.0,>=5.0.0->sae-dashboard) (5.24.1)
# Requirement already satisfied: plotly-express<0.5.0,>=0.4.1 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from sae-lens<6.0.0,>=5.0.0->sae-dashboard) (0.4.1)
# Requirement already satisfied: pytest-profiling<2.0.0,>=1.7.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from sae-lens<6.0.0,>=5.0.0->sae-dashboard) (1.8.1)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.1 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from sae-lens<6.0.0,>=5.0.0->sae-dashboard) (1.2.1)
# Requirement already satisfied: pyzmq==26.0.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from sae-lens<6.0.0,>=5.0.0->sae-dashboard) (26.0.0)
# Requirement already satisfied: simple-parsing<0.2.0,>=0.1.6 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from sae-lens<6.0.0,>=5.0.0->sae-dashboard) (0.1.7)
# Requirement already satisfied: transformers<5.0.0,>=4.38.1 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from sae-lens<6.0.0,>=5.0.0->sae-dashboard) (4.57.6)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.10.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from sae-lens<6.0.0,>=5.0.0->sae-dashboard) (4.15.0)
# Requirement already satisfied: zstandard<0.23.0,>=0.22.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from sae-lens<6.0.0,>=5.0.0->sae-dashboard) (0.22.0)
# Requirement already satisfied: blobfile<3.0.0,>=2.1.1 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from automated-interpretability<1.0.0,>=0.0.5->sae-lens<6.0.0,>=5.0.0->sae-dashboard) (2.1.1)
# Requirement already satisfied: boostedblob<0.16.0,>=0.15.3 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from automated-interpretability<1.0.0,>=0.0.5->sae-lens<6.0.0,>=5.0.0->sae-dashboard) (0.15.6)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from automated-interpretability<1.0.0,>=0.0.5->sae-lens<6.0.0,>=5.0.0->sae-dashboard) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.10.1 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from automated-interpretability<1.0.0,>=0.0.5->sae-lens<6.0.0,>=5.0.0->sae-dashboard) (3.11.5)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.2.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from automated-interpretability<1.0.0,>=0.0.5->sae-lens<6.0.0,>=5.0.0->sae-dashboard) (1.8.0)
# Requirement already satisfied: tiktoken>=0.6.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from automated-interpretability<1.0.0,>=0.0.5->sae-lens<6.0.0,>=5.0.0->sae-dashboard) (0.12.0)
# Requirement already satisfied: py2store in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from babe<0.0.8,>=0.0.7->sae-lens<6.0.0,>=5.0.0->sae-dashboard) (0.1.22)
# Requirement already satisfied: graze in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from babe<0.0.8,>=0.0.7->sae-lens<6.0.0,>=5.0.0->sae-dashboard) (0.1.39)
# Requirement already satisfied: pycryptodomex~=3.8 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from blobfile<3.0.0,>=2.1.1->automated-interpretability<1.0.0,>=0.0.5->sae-lens<6.0.0,>=5.0.0->sae-dashboard) (3.23.0)
# Requirement already satisfied: urllib3<3,>=1.25.3 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from blobfile<3.0.0,>=2.1.1->automated-interpretability<1.0.0,>=0.0.5->sae-lens<6.0.0,>=5.0.0->sae-dashboard) (2.6.3)
# Requirement already satisfied: lxml~=4.9 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from blobfile<3.0.0,>=2.1.1->automated-interpretability<1.0.0,>=0.0.5->sae-lens<6.0.0,>=5.0.0->sae-dashboard) (4.9.4)
# Requirement already satisfied: traitlets in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from matplotlib-inline<0.2.0,>=0.1.6->sae-lens<6.0.0,>=5.0.0->sae-dashboard) (5.14.3)
# Requirement already satisfied: click in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from nltk<4.0.0,>=3.8.1->sae-lens<6.0.0,>=5.0.0->sae-dashboard) (8.2.1)
# Requirement already satisfied: joblib in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from nltk<4.0.0,>=3.8.1->sae-lens<6.0.0,>=5.0.0->sae-dashboard) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from nltk<4.0.0,>=3.8.1->sae-lens<6.0.0,>=5.0.0->sae-dashboard) (2026.1.15)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from plotly<6.0.0,>=5.19.0->sae-lens<6.0.0,>=5.0.0->sae-dashboard) (9.1.2)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from plotly-express<0.5.0,>=0.4.1->sae-lens<6.0.0,>=5.0.0->sae-dashboard) (0.14.6)
# Requirement already satisfied: scipy>=0.18 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from plotly-express<0.5.0,>=0.4.1->sae-lens<6.0.0,>=5.0.0->sae-dashboard) (1.17.0)
# Requirement already satisfied: patsy>=0.5 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from plotly-express<0.5.0,>=0.4.1->sae-lens<6.0.0,>=5.0.0->sae-dashboard) (1.0.2)
# Requirement already satisfied: six in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from pytest-profiling<2.0.0,>=1.7.0->sae-lens<6.0.0,>=5.0.0->sae-dashboard) (1.17.0)
# Requirement already satisfied: pytest in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from pytest-profiling<2.0.0,>=1.7.0->sae-lens<6.0.0,>=5.0.0->sae-dashboard) (9.0.2)
# Requirement already satisfied: gprof2dot in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from pytest-profiling<2.0.0,>=1.7.0->sae-lens<6.0.0,>=5.0.0->sae-dashboard) (2025.4.14)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from scikit-learn<2.0.0,>=1.2.0->automated-interpretability<1.0.0,>=0.0.5->sae-lens<6.0.0,>=5.0.0->sae-dashboard) (3.6.0)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from simple-parsing<0.2.0,>=0.1.6->sae-lens<6.0.0,>=5.0.0->sae-dashboard) (0.17.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from torch<3.0.0,>=2.0.0->sae-dashboard) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from torch<3.0.0,>=2.0.0->sae-dashboard) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from torch<3.0.0,>=2.0.0->sae-dashboard) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from torch<3.0.0,>=2.0.0->sae-dashboard) (80.9.0)
# Requirement already satisfied: accelerate>=0.23.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from transformer-lens<3.0.0,>=2.2.0->sae-dashboard) (1.12.0)
# Requirement already satisfied: beartype<0.15.0,>=0.14.1 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from transformer-lens<3.0.0,>=2.2.0->sae-dashboard) (0.14.1)
# Requirement already satisfied: better-abc<0.0.4,>=0.0.3 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from transformer-lens<3.0.0,>=2.2.0->sae-dashboard) (0.0.3)
# Requirement already satisfied: fancy-einsum>=0.0.3 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from transformer-lens<3.0.0,>=2.2.0->sae-dashboard) (0.0.3)
# Requirement already satisfied: sentencepiece in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from transformer-lens<3.0.0,>=2.2.0->sae-dashboard) (0.2.1)
# Requirement already satisfied: transformers-stream-generator<0.0.6,>=0.0.5 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from transformer-lens<3.0.0,>=2.2.0->sae-dashboard) (0.0.5)
# Requirement already satisfied: typeguard<5.0,>=4.2 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from transformer-lens<3.0.0,>=2.2.0->sae-dashboard) (4.4.4)
# Requirement already satisfied: wandb>=0.13.5 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from transformer-lens<3.0.0,>=2.2.0->sae-dashboard) (0.24.0)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from transformers<5.0.0,>=4.38.1->sae-lens<6.0.0,>=5.0.0->sae-dashboard) (0.22.2)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from typer<0.13.0,>=0.12.3->sae-dashboard) (1.5.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.4->sae-dashboard) (1.1.0)
# Requirement already satisfied: psutil in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from accelerate>=0.23.0->transformer-lens<3.0.0,>=2.2.0->sae-dashboard) (7.2.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from aiohttp->datasets<3.0.0,>=2.0.0->sae-dashboard) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from aiohttp->datasets<3.0.0,>=2.0.0->sae-dashboard) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from aiohttp->datasets<3.0.0,>=2.0.0->sae-dashboard) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from aiohttp->datasets<3.0.0,>=2.0.0->sae-dashboard) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from aiohttp->datasets<3.0.0,>=2.0.0->sae-dashboard) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from aiohttp->datasets<3.0.0,>=2.0.0->sae-dashboard) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from aiohttp->datasets<3.0.0,>=2.0.0->sae-dashboard) (1.22.0)
# Requirement already satisfied: idna>=2.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp->datasets<3.0.0,>=2.0.0->sae-dashboard) (3.11)
# Requirement already satisfied: colorama in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from click->nltk<4.0.0,>=3.8.1->sae-lens<6.0.0,>=5.0.0->sae-dashboard) (0.4.6)
# Requirement already satisfied: anyio in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from httpx>=0.27.0->automated-interpretability<1.0.0,>=0.0.5->sae-lens<6.0.0,>=5.0.0->sae-dashboard) (4.12.1)
# Requirement already satisfied: certifi in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from httpx>=0.27.0->automated-interpretability<1.0.0,>=0.0.5->sae-lens<6.0.0,>=5.0.0->sae-dashboard) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from httpx>=0.27.0->automated-interpretability<1.0.0,>=0.0.5->sae-lens<6.0.0,>=5.0.0->sae-dashboard) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->automated-interpretability<1.0.0,>=0.0.5->sae-lens<6.0.0,>=5.0.0->sae-dashboard) (0.16.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.7.1->sae-dashboard) (0.1.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from pandas->datasets<3.0.0,>=2.0.0->sae-dashboard) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from pandas->datasets<3.0.0,>=2.0.0->sae-dashboard) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from requests>=2.32.2->datasets<3.0.0,>=2.0.0->sae-dashboard) (3.4.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from sympy>=1.13.3->torch<3.0.0,>=2.0.0->sae-dashboard) (1.3.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from wandb>=0.13.5->transformer-lens<3.0.0,>=2.2.0->sae-dashboard) (3.1.46)
# Requirement already satisfied: platformdirs in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from wandb>=0.13.5->transformer-lens<3.0.0,>=2.2.0->sae-dashboard) (4.5.1)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from wandb>=0.13.5->transformer-lens<3.0.0,>=2.2.0->sae-dashboard) (6.33.4)
# Requirement already satisfied: pydantic<3 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from wandb>=0.13.5->transformer-lens<3.0.0,>=2.2.0->sae-dashboard) (2.12.5)
# Requirement already satisfied: sentry-sdk>=2.0.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from wandb>=0.13.5->transformer-lens<3.0.0,>=2.2.0->sae-dashboard) (2.49.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from pydantic<3->wandb>=0.13.5->transformer-lens<3.0.0,>=2.2.0->sae-dashboard) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from pydantic<3->wandb>=0.13.5->transformer-lens<3.0.0,>=2.2.0->sae-dashboard) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from pydantic<3->wandb>=0.13.5->transformer-lens<3.0.0,>=2.2.0->sae-dashboard) (0.4.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from gitpython!=3.1.29,>=1.0.0->wandb>=0.13.5->transformer-lens<3.0.0,>=2.2.0->sae-dashboard) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.13.5->transformer-lens<3.0.0,>=2.2.0->sae-dashboard) (5.0.2)
# Requirement already satisfied: dol in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from graze->babe<0.0.8,>=0.0.7->sae-lens<6.0.0,>=5.0.0->sae-dashboard) (0.3.38)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from jinja2->torch<3.0.0,>=2.0.0->sae-dashboard) (3.0.3)
# Requirement already satisfied: config2py in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from py2store->babe<0.0.8,>=0.0.7->sae-lens<6.0.0,>=5.0.0->sae-dashboard) (0.1.45)
# Requirement already satisfied: importlib_resources in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from py2store->babe<0.0.8,>=0.0.7->sae-lens<6.0.0,>=5.0.0->sae-dashboard) (6.5.2)
# Requirement already satisfied: i2 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from config2py->py2store->babe<0.0.8,>=0.0.7->sae-lens<6.0.0,>=5.0.0->sae-dashboard) (0.1.63)
# Requirement already satisfied: iniconfig>=1.0.1 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from pytest->pytest-profiling<2.0.0,>=1.7.0->sae-lens<6.0.0,>=5.0.0->sae-dashboard) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\lab622_tv\miniforge3\envs\mi\lib\site-packages (from pytest->pytest-profiling<2.0.0,>=1.7.0->sae-lens<6.0.0,>=5.0.0->sae-dashboard) (1.6.0)

# %% [markdown]
# # Other Test

# %%
# GPU Memory measurement helper
class GPUMemMeasure:
  def __init__(self):
    self.model_mem_dict = {}
    self.initial_mem = 0

  def begin(self, model_name: str):
    if torch.cuda.is_available():
      # Clear cache for more accurate measurement
      torch.cuda.empty_cache()
      # Initial memory usage
      self.initial_mem = torch.cuda.memory_allocated()
      print(f"Initial GPU memory allocated: {self.initial_mem / (1024**2):.2f} MB")
      self.model_mem_dict[model_name] = self.initial_mem
    else:
      print("CUDA is not available. Cannot measure GPU memory.")

  def after(self, model_name: str):
    if torch.cuda.is_available():
      model_mem_after = torch.cuda.memory_allocated()
      model_allocated_mem = model_mem_after - self.model_mem_dict[model_name]
      self.model_mem_dict[model_name] = model_allocated_mem # Store for later use if needed
      print(f"GPU memory used by {model_name}: {model_allocated_mem / (1024**2):.2f} MB")
    else:
      print("CUDA is not available. Cannot measure GPU memory.")

  def print_mem(self):
    if torch.cuda.is_available():
      total_mem = torch.cuda.memory_allocated()
      print(f"Total GPU memory currently allocated: {total_mem / (1024**2):.2f} MB")
      total_gpu_mem = torch.cuda.get_device_properties(0).total_memory
      print(f"Total GPU memory available on device 0: {total_gpu_mem / (1024**3):.2f} GB")
      reserved_mem = torch.cuda.memory_reserved()
      print(f"Total GPU memory reserved by PyTorch: {reserved_mem / (1024**2):.2f} MB")
      print()
      for model_mame, model_mem in self.model_mem_dict.items():
        print(f"GPU memory used by {model_mame}: {model_mem / (1024**2):.2f} MB")

    else:
      print("CUDA is not available. Cannot measure GPU memory.")

# %%
from nnsight import LanguageModel
from sae_lens import SAE

# Measure GPU Memory usage
mem_measure = GPUMemMeasure()


mem_measure.begin("SAE")
# Load SAE
sae = SAE.from_pretrained(
    release="gemma-scope-2b-pt-res-canonical",
    sae_id="layer_12/width_16k/canonical",
    device="cuda"
)
mem_measure.after("SAE")


# Load model with nnsight

mem_measure.begin("model")
model = LanguageModel("google/gemma-2-2b", device_map="auto", torch_dtype=t.bfloat16)
mem_measure.after("model")
# Out:
# Initial GPU memory allocated: 10270.53 MB
# GPU memory used by SAE: 0.00 MB
# Initial GPU memory allocated: 10270.53 MB
# GPU memory used by model: 0.00 MB

# %%
prompt = "The Eiffel Tower is in"

# Extract activations and compute SAE features
with model.trace(prompt):
    # Access hidden states at layer 12
    hidden_states = model.model.layers[12].output[0]

    # Save the hidden states
    hidden_states_saved = hidden_states.save()


# Get SAE features outside the trace
with torch.no_grad():
    features = sae.encode(hidden_states_saved)

print(f"Feature activations shape: {features.shape}")
print(f"Average L0: {(features[:, 1:, :] > 0).sum(dim=-1).float().mean().item():.1f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2579322094.py in <cell line: 0>()
#       2
#       3 # Extract activations and compute SAE features
# ----> 4 with model.trace(prompt):
#       5     # Access hidden states at layer 12
#       6     hidden_states = model.model.layers[12].output[0]
#
# NameError: name 'model' is not defined

# %%
hidden_states_memory_bytes = hidden_states_saved.element_size() * hidden_states_saved.nelement()
print(f"Hidden states memory usage: {hidden_states_memory_bytes / (1024**2):.2f} MB")
# Out:
# Hidden states memory usage: 0.03 MB
